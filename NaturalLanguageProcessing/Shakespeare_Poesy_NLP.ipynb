# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import tensorflow.keras.utils as ku 
import numpy as np

# %%
tokenizer = Tokenizer()
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sonnets.txt \
    -O /tmp/sonnets.txt
data = open('/tmp/sonnets.txt').read()

corpus = data.lower().split("\n")


tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

# create input sequences using list of tokens
input_sequences = []
for line in corpus:
	token_list = tokenizer.texts_to_sequences([line])[0]
	for i in range(1, len(token_list)):
		n_gram_sequence = token_list[:i+1]
		input_sequences.append(n_gram_sequence)


# pad sequences 
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# create predictors and label
predictors, label = input_sequences[:,:-1],input_sequences[:,-1]

label = ku.to_categorical(label, num_classes=total_words)
# Out:
# --2020-12-29 17:00:00--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sonnets.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.195.128, 74.125.142.128, 142.250.107.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93578 (91K) [text/plain]
# Saving to: ‘/tmp/sonnets.txt’
#
# /tmp/sonnets.txt    100%[===================>]  91.38K  --.-KB/s    in 0.001s
#
# 2020-12-29 17:00:00 (156 MB/s) - ‘/tmp/sonnets.txt’ saved [93578/93578]

# %%
model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
model.add(Bidirectional(LSTM(150, return_sequences = True)))
model.add(Dropout(0.2))
model.add(LSTM(100))
model.add(Dense(total_words/2, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(total_words, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 10, 100)           321100
# _________________________________________________________________
# bidirectional (Bidirectional (None, 10, 300)           301200
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 300)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               160400
# _________________________________________________________________
# dense (Dense)                (None, 1605)              162105
# _________________________________________________________________
# dense_1 (Dense)              (None, 3211)              5156866
# =================================================================
# Total params: 6,101,671
# Trainable params: 6,101,671
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
 history = model.fit(predictors, label, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 484/484 [==============================] - 16s 12ms/step - loss: 7.3213 - accuracy: 0.0208
# Epoch 2/100
# 484/484 [==============================] - 6s 12ms/step - loss: 6.4856 - accuracy: 0.0179
# Epoch 3/100
# 484/484 [==============================] - 6s 12ms/step - loss: 6.3658 - accuracy: 0.0278
# Epoch 4/100
# 484/484 [==============================] - 5s 11ms/step - loss: 6.2485 - accuracy: 0.0287
# Epoch 5/100
# 484/484 [==============================] - 6s 12ms/step - loss: 6.1680 - accuracy: 0.0356
# Epoch 6/100
# 484/484 [==============================] - 6s 12ms/step - loss: 6.0705 - accuracy: 0.0383
# Epoch 7/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.9951 - accuracy: 0.0438
# Epoch 8/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.9084 - accuracy: 0.0476
# Epoch 9/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.8009 - accuracy: 0.0519
# Epoch 10/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.7252 - accuracy: 0.0587
# Epoch 11/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.5883 - accuracy: 0.0690
# Epoch 12/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.5134 - accuracy: 0.0710
# Epoch 13/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.3828 - accuracy: 0.0791
# Epoch 14/100
# 484/484 [==============================] - 6s 13ms/step - loss: 5.2858 - accuracy: 0.0834
# Epoch 15/100
# 484/484 [==============================] - 6s 13ms/step - loss: 5.2135 - accuracy: 0.0903
# Epoch 16/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.0834 - accuracy: 0.0955
# Epoch 17/100
# 484/484 [==============================] - 6s 12ms/step - loss: 5.0080 - accuracy: 0.1029
# Epoch 18/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.8691 - accuracy: 0.1146
# Epoch 19/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.7920 - accuracy: 0.1156
# Epoch 20/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.6379 - accuracy: 0.1338
# Epoch 21/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.5485 - accuracy: 0.1415
# Epoch 22/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.4447 - accuracy: 0.1529
# Epoch 23/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.3612 - accuracy: 0.1627
# Epoch 24/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.2208 - accuracy: 0.1798
# Epoch 25/100
# 484/484 [==============================] - 6s 13ms/step - loss: 4.1287 - accuracy: 0.1889
# Epoch 26/100
# 484/484 [==============================] - 6s 12ms/step - loss: 4.0180 - accuracy: 0.2052
# Epoch 27/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.8794 - accuracy: 0.2276
# Epoch 28/100
# 484/484 [==============================] - 6s 13ms/step - loss: 3.8150 - accuracy: 0.2380
# Epoch 29/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.7091 - accuracy: 0.2579
# Epoch 30/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.6068 - accuracy: 0.2747
# Epoch 31/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.5452 - accuracy: 0.2940
# Epoch 32/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.4023 - accuracy: 0.3252
# Epoch 33/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.3281 - accuracy: 0.3382
# Epoch 34/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.2390 - accuracy: 0.3664
# Epoch 35/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.1492 - accuracy: 0.3823
# Epoch 36/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.0356 - accuracy: 0.4144
# Epoch 37/100
# 484/484 [==============================] - 6s 12ms/step - loss: 3.0014 - accuracy: 0.4175
# Epoch 38/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.9086 - accuracy: 0.4470
# Epoch 39/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.8582 - accuracy: 0.4475
# Epoch 40/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.7691 - accuracy: 0.4708
# Epoch 41/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.7253 - accuracy: 0.4817
# Epoch 42/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.6373 - accuracy: 0.5042
# Epoch 43/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.6098 - accuracy: 0.5134
# Epoch 44/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.5474 - accuracy: 0.5221
# Epoch 45/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.4524 - accuracy: 0.5392
# Epoch 46/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.4160 - accuracy: 0.5437
# Epoch 47/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.3707 - accuracy: 0.5562
# Epoch 48/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.3562 - accuracy: 0.5656
# Epoch 49/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.2542 - accuracy: 0.5816
# Epoch 50/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.2162 - accuracy: 0.5923
# Epoch 51/100
# 484/484 [==============================] - 6s 13ms/step - loss: 2.1586 - accuracy: 0.6014
# Epoch 52/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.1389 - accuracy: 0.6103
# Epoch 53/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.0912 - accuracy: 0.6213
# Epoch 54/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.0740 - accuracy: 0.6290
# Epoch 55/100
# 484/484 [==============================] - 6s 12ms/step - loss: 2.0172 - accuracy: 0.6356
# Epoch 56/100
# 484/484 [==============================] - 6s 13ms/step - loss: 1.9609 - accuracy: 0.6499
# Epoch 57/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.9306 - accuracy: 0.6573
# Epoch 58/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.9083 - accuracy: 0.6605
# Epoch 59/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.8621 - accuracy: 0.6676
# Epoch 60/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.8482 - accuracy: 0.6735
# Epoch 61/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.8007 - accuracy: 0.6857
# Epoch 62/100
# 484/484 [==============================] - 6s 13ms/step - loss: 1.7725 - accuracy: 0.6905
# Epoch 63/100
# 484/484 [==============================] - 6s 13ms/step - loss: 1.7677 - accuracy: 0.6893
# Epoch 64/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.7108 - accuracy: 0.7061
# Epoch 65/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.7048 - accuracy: 0.7062
# Epoch 66/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.6815 - accuracy: 0.7105
# Epoch 67/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.6426 - accuracy: 0.7192
# Epoch 68/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.5989 - accuracy: 0.7231
# Epoch 69/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.5774 - accuracy: 0.7284
# Epoch 70/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.5579 - accuracy: 0.7340
# Epoch 71/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.5285 - accuracy: 0.7349
# Epoch 72/100
# 484/484 [==============================] - 6s 13ms/step - loss: 1.5444 - accuracy: 0.7320
# Epoch 73/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.5267 - accuracy: 0.7344
# Epoch 74/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.4854 - accuracy: 0.7414
# Epoch 75/100
# 484/484 [==============================] - 6s 13ms/step - loss: 1.4537 - accuracy: 0.7521
# Epoch 76/100
# 484/484 [==============================] - 6s 13ms/step - loss: 1.4506 - accuracy: 0.7511
# Epoch 77/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.4476 - accuracy: 0.7507
# Epoch 78/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.4212 - accuracy: 0.7584
# Epoch 79/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.3759 - accuracy: 0.7625
# Epoch 80/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.3756 - accuracy: 0.7605
# Epoch 81/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.3679 - accuracy: 0.7668
# Epoch 82/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.3264 - accuracy: 0.7739
# Epoch 83/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.3306 - accuracy: 0.7747
# Epoch 84/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.3151 - accuracy: 0.7794
# Epoch 85/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.3234 - accuracy: 0.7734
# Epoch 86/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.2904 - accuracy: 0.7801
# Epoch 87/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.2875 - accuracy: 0.7806
# Epoch 88/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.2670 - accuracy: 0.7849
# Epoch 89/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.2460 - accuracy: 0.7829
# Epoch 90/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.2276 - accuracy: 0.7926
# Epoch 91/100
# 484/484 [==============================] - 6s 11ms/step - loss: 1.2155 - accuracy: 0.7945
# Epoch 92/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.2115 - accuracy: 0.7924
# Epoch 93/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1986 - accuracy: 0.7952
# Epoch 94/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1852 - accuracy: 0.7981
# Epoch 95/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1705 - accuracy: 0.7981
# Epoch 96/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1659 - accuracy: 0.8028
# Epoch 97/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1803 - accuracy: 0.7961
# Epoch 98/100
# 484/484 [==============================] - 5s 11ms/step - loss: 1.1461 - accuracy: 0.8040
# Epoch 99/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1396 - accuracy: 0.8043
# Epoch 100/100
# 484/484 [==============================] - 6s 12ms/step - loss: 1.1262 - accuracy: 0.8079

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
loss = history.history['loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.title('Training accuracy')

plt.figure()

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.title('Training loss')
plt.legend()

plt.show()

# %%
seed_text = "Pringles"
next_words = 13
  
for _ in range(next_words):
	token_list = tokenizer.texts_to_sequences([seed_text])[0]
	token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
	predicted = model.predict_classes(token_list, verbose=0)
	output_word = ""
	for word, index in tokenizer.word_index.items():
		if index == predicted:
			output_word = word
			break
	seed_text += " " + output_word
print(seed_text)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Pringles in many's looks the false heart's history state to go hate hate '

# %%
seed_text.split(' \' ')
# Out:
# ["Pringles in many's looks the false heart's history state to go hate hate '"]
